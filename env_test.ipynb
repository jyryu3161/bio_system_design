# %%
import cobra
import gurobipy

# %%
import cobra
# 예시 모델 로드
model = cobra.io.load_model("textbook")

# 현재 설정된 solver 확인
from optlang import available_solvers
print(available_solvers)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2733080
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import cobra
#       2 # 예시 모델 로드
# ----> 3 model = cobra.io.load_model("textbook")
#       5 # 현재 설정된 solver 확인
#       6 from optlang import available_solvers
#
# File ~/Projects/gem/.pixi/envs/default/lib/python3.10/site-packages/cobra/io/web/load.py:94, in load_model(model_id, repositories, cache)
#      92 else:
#      93     data = _fetch_model(model_id=model_id, repositories=repositories)
# ---> 94 return get_model_from_gzip_sbml(data)
#
# File ~/Projects/gem/.pixi/envs/default/lib/python3.10/site-packages/cobra/io/web/load.py:198, in get_model_from_gzip_sbml(stream)
#     183 def get_model_from_gzip_sbml(stream: bytes) -> "Model":
#     184     """
# ...
